# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import Train Data Sets From Database
Train_Data=pd.read_csv("dwt.csv")
Train_Data.head()
# Out:
#    0   -5  1.436  1.434  1.441  1.4505  1.45725         0.004  0.002  -0.007  \
# 0  0 -5.0  1.436  1.434  1.441  1.4505  1.45725 -4.000000e-03  0.002  -0.007
# 1  0 -5.0  1.432  1.434  1.441  1.4505  1.45725  4.330000e-17 -0.002  -0.007
# 2  0 -5.0  1.432  1.434  1.441  1.4505  1.45725 -4.330000e-17 -0.002  -0.007
# 3  0 -5.0  1.444  1.448  1.441  1.4505  1.45725 -1.200000e-02 -0.004   0.007
# 4  0 -5.0  1.444  1.448  1.441  1.4505  1.45725  1.200000e-02 -0.004   0.007
#
#    ...  0.82  0.835  0.86  0.8925  0.99125     -3.54E-17  -0.015  -0.025.1  \
# 0  ...  0.82  0.835  0.86  0.8925  0.99125  3.540000e-17  -0.015    -0.025
# 1  ...  0.85  0.835  0.86  0.8925  0.99125 -1.000000e-02   0.015    -0.025
# 2  ...  0.85  0.835  0.86  0.8925  0.99125  1.000000e-02   0.015    -0.025
# 3  ...  0.87  0.885  0.86  0.8925  0.99125 -1.000000e-02  -0.015     0.025
# 4  ...  0.87  0.885  0.86  0.8925  0.99125  1.000000e-02  -0.015     0.025
#
#    -0.0325  -0.09875
# 0  -0.0325  -0.09875
# ...

# %%
# adding column name to the respective columns
Train_Data.columns =['Target','Time', 'ba1', 'ba2','ba3','ba4','ba5','bd1', 'bd2','bd3','bd4','bd5','ca1','ca2','ca3','ca4','ca5', 'cd1', 'cd2','cd3','cd4','cd5','da1','da2','da3','da4','da5','dd1','dd2','dd3','dd4','dd5','ea1','ea2','ea3','ea4','ea5','ed1','ed2','ed3','ed4','ed5']
  
# displaying the DataFrame
print(Train_Data)
# Out:
#       Target  Time    ba1    ba2    ba3     ba4      ba5           bd1    bd2  \
# 0          0 -5.00  1.436  1.434  1.441  1.4505  1.45725 -4.000000e-03  0.002
# 1          0 -5.00  1.432  1.434  1.441  1.4505  1.45725  4.330000e-17 -0.002
# 2          0 -5.00  1.432  1.434  1.441  1.4505  1.45725 -4.330000e-17 -0.002
# 3          0 -5.00  1.444  1.448  1.441  1.4505  1.45725 -1.200000e-02 -0.004
# 4          0 -5.00  1.444  1.448  1.441  1.4505  1.45725  1.200000e-02 -0.004
# ...      ...   ...    ...    ...    ...     ...      ...           ...    ...
# 3645       3 -4.03  1.408  1.432  1.438  1.4370  1.47150  3.200000e-02 -0.024
# 3646       3 -4.03  1.408  1.432  1.438  1.4370  1.47150 -3.200000e-02 -0.024
# 3647       3 -4.03  1.396  1.390  1.390  1.3900  1.39000 -4.000000e-03  0.006
# 3648       3 -4.03  1.396  1.390  1.390  1.3900  1.39000  4.000000e-03  0.006
# 3649       3 -4.03  1.384  1.390  1.390  1.3900  1.39000  1.380000e-17 -0.006
#
# ...

# %%
#import Test Data Sets From Database
Test_Data=pd.read_csv("dwt_test.csv")
Test_Data.head()
# Out:
#     -5  1.436  1.434  1.441  1.4505  1.45725         0.004  0.002  -0.007  \
# 0 -5.0  1.436  1.434  1.441  1.4505  1.45725 -4.000000e-03  0.002  -0.007
# 1 -5.0  1.432  1.434  1.441  1.4505  1.45725  4.330000e-17 -0.002  -0.007
# 2 -5.0  1.432  1.434  1.441  1.4505  1.45725 -4.330000e-17 -0.002  -0.007
# 3 -5.0  1.444  1.448  1.441  1.4505  1.45725 -1.200000e-02 -0.004   0.007
# 4 -5.0  1.444  1.448  1.441  1.4505  1.45725  1.200000e-02 -0.004   0.007
#
#    -0.0095  ...  0.82  0.835  0.86  0.8925  0.99125     -3.54E-17  -0.015  \
# 0  -0.0095  ...  0.82  0.835  0.86  0.8925  0.99125  3.540000e-17  -0.015
# 1  -0.0095  ...  0.85  0.835  0.86  0.8925  0.99125 -1.000000e-02   0.015
# 2  -0.0095  ...  0.85  0.835  0.86  0.8925  0.99125  1.000000e-02   0.015
# 3  -0.0095  ...  0.87  0.885  0.86  0.8925  0.99125 -1.000000e-02  -0.015
# 4  -0.0095  ...  0.87  0.885  0.86  0.8925  0.99125  1.000000e-02  -0.015
#
#    -0.025.1  -0.0325  -0.09875
# 0    -0.025  -0.0325  -0.09875
# ...

# %%
# adding column name to the respective columns
Test_Data.columns =['Time', 'ba1', 'ba2','ba3','ba4','ba5','bd1', 'bd2','bd3','bd4','bd5','ca1','ca2','ca3','ca4','ca5', 'cd1', 'cd2','cd3','cd4','cd5','da1','da2','da3','da4','da5','dd1','dd2','dd3','dd4','dd5','ea1','ea2','ea3','ea4','ea5','ed1','ed2','ed3','ed4','ed5']
  
# displaying the DataFrame
print(Test_Data)
# Out:
#       Time    ba1    ba2    ba3     ba4      ba5           bd1    bd2  \
# 0    -5.00  1.436  1.434  1.441  1.4505  1.45725 -4.000000e-03  0.002
# 1    -5.00  1.432  1.434  1.441  1.4505  1.45725  4.330000e-17 -0.002
# 2    -5.00  1.432  1.434  1.441  1.4505  1.45725 -4.330000e-17 -0.002
# 3    -5.00  1.444  1.448  1.441  1.4505  1.45725 -1.200000e-02 -0.004
# 4    -5.00  1.444  1.448  1.441  1.4505  1.45725  1.200000e-02 -0.004
# ...    ...    ...    ...    ...     ...      ...           ...    ...
# 3645 -4.03  1.408  1.432  1.438  1.4370  1.47150  3.200000e-02 -0.024
# 3646 -4.03  1.408  1.432  1.438  1.4370  1.47150 -3.200000e-02 -0.024
# 3647 -4.03  1.396  1.390  1.390  1.3900  1.39000 -4.000000e-03  0.006
# 3648 -4.03  1.396  1.390  1.390  1.3900  1.39000  4.000000e-03  0.006
# 3649 -4.03  1.384  1.390  1.390  1.3900  1.39000  1.380000e-17 -0.006
#
#                bd3           bd4  ...   ea1    ea2     ea3     ea4      ea5  \
# ...

# %%
Train_Data.shape # Count total Shape of data Avaloade in Datasts
# Out:
# (3650, 42)

# %%
Test_Data.shape
# Out:
# (3650, 41)

# %%
X = Train_Data
y = Test_Data

X_train, X_test, y_train, y_test = train_test_split(Train_Data, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
#       Target  Time    ba1    ba2    ba3     ba4      ba5           bd1  \
# 2885       3 -4.11  1.600  1.600  1.582  1.5895  1.62625  8.000000e-03
# 3187       3 -4.08  1.600  1.590  1.600  1.5620  1.58350 -4.980000e-17
# 1103       5 -3.85  1.832  1.820  1.810  1.8215  1.78050  4.710000e-17
# 1896       6 -3.61  1.588  1.592  1.574  1.5575  1.51725  4.000000e-03
# 3525       3 -4.04  1.508  1.538  1.565  1.5175  1.52875  2.000000e-02
# ...      ...   ...    ...    ...    ...     ...      ...           ...
# 1130       5 -3.85  1.760  1.764  1.751  1.7850  1.70725 -8.000000e-03
# 1294       6 -3.67  1.612  1.582  1.592  1.6265  1.67725  9.200000e-02
# 860        4 -3.87  1.624  1.628  1.623  1.5915  1.54700 -4.200000e-18
# 3507       3 -4.05  1.584  1.570  1.598  1.5715  1.63975  8.000000e-03
# 3174       3 -4.08  1.604  1.602  1.619  1.6050  1.58350  1.200000e-02
#
#                bd2    bd3  ...   ea1    ea2     ea3      ea4       ea5  \
# ...

# %%
X_test
# Out:
#       Target  Time    ba1    ba2    ba3     ba4      ba5           bd1    bd2  \
# 1313       6 -3.67  1.660  1.680  1.637  1.5960  1.55875  4.000000e-03 -0.020
# 1674       6 -3.63  1.424  1.438  1.415  1.4520  1.42575 -8.000000e-03 -0.014
# 229        0 -4.98  1.444  1.466  1.507  1.5000  1.49600  4.000000e-03 -0.022
# 2974       3 -4.10  1.472  1.480  1.481  1.4785  1.52025 -2.400000e-02 -0.008
# 2222       2 -4.17  1.632  1.622  1.605  1.5755  1.60475  8.000000e-03  0.010
# ...      ...   ...    ...    ...    ...     ...      ...           ...    ...
# 1618       6 -3.64  1.724  1.732  1.708  1.6985  1.69075 -4.000000e-03 -0.008
# 819        4 -3.88  1.600  1.588  1.588  1.5395  1.57250 -4.980000e-17  0.012
# 100        0 -4.99  1.576  1.560  1.585  1.5430  1.54175 -5.320000e-17  0.016
# 3208       3 -4.08  1.544  1.546  1.564  1.5500  1.60250  1.600000e-02 -0.002
# 3371       3 -4.06  1.700  1.686  1.700  1.7245  1.67050 -2.000000e-02  0.014
#
# ...

# %%
Train_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 42 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Target  3650 non-null   int64
#  1   Time    3650 non-null   float64
#  2   ba1     3650 non-null   float64
#  3   ba2     3650 non-null   float64
#  4   ba3     3650 non-null   float64
#  5   ba4     3650 non-null   float64
#  6   ba5     3650 non-null   float64
#  7   bd1     3650 non-null   float64
#  8   bd2     3650 non-null   float64
#  9   bd3     3650 non-null   float64
#  10  bd4     3650 non-null   float64
#  11  bd5     3650 non-null   float64
#  12  ca1     3650 non-null   float64
#  13  ca2     3650 non-null   float64
#  14  ca3     3650 non-null   float64
#  15  ca4     3650 non-null   float64
#  16  ca5     3650 non-null   float64
#  17  cd1     3650 non-null   float64
#  18  cd2     3650 non-null   float64
#  19  cd3     3650 non-null   float64
# ...

# %%
Train_Data.describe()
# Out:
#             Target         Time          ba1          ba2          ba3  \
# count  3650.000000  3650.000000  3650.000000  3650.000000  3650.000000
# mean      3.039452    -4.131458     1.618298     1.618297     1.618295
# std       1.882134     0.389782     0.111232     0.110426     0.108543
# min       0.000000    -5.000000     1.296000     1.312000     1.333000
# 25%       2.000000    -4.190000     1.532000     1.532000     1.536000
# 50%       3.000000    -4.100000     1.620000     1.620000     1.618000
# 75%       4.000000    -3.860000     1.700000     1.704000     1.698000
# max       6.000000    -3.610000     1.904000     1.888000     1.875000
#
#                ba4          ba5          bd1          bd2           bd3  ...  \
# count  3650.000000  3650.000000  3650.000000  3650.000000  3.650000e+03  ...
# mean      1.618292     1.618291    -0.000001     0.000001  1.917808e-06  ...
# std       0.103749     0.094298     0.011485     0.013388  2.032123e-02  ...
# ...

# %%
Train_Data.isna().sum()  #Find the Null values in Data Sets using isna() and count using sum()
# Out:
# Target    0
# Time      0
# ba1       0
# ba2       0
# ba3       0
# ba4       0
# ba5       0
# bd1       0
# bd2       0
# bd3       0
# bd4       0
# bd5       0
# ca1       0
# ca2       0
# ca3       0
# ca4       0
# ca5       0
# cd1       0
# cd2       0
# cd3       0
# cd4       0
# cd5       0
# da1       0
# da2       0
# da3       0
# da4       0
# da5       0
# dd1       0
# dd2       0
# dd3       0
# dd4       0
# dd5       0
# ea1       0
# ea2       0
# ea3       0
# ea4       0
# ea5       0
# ed1       0
# ed2       0
# ed3       0
# ed4       0
# ed5       0
# dtype: int64

# %%
X=Train_Data.drop(['ba3', 'bd2'],axis=1)   # Independent Variables
X.head()
# Out:
#    Target  Time    ba1    ba2     ba4      ba5           bd1    bd3     bd4  \
# 0       0  -5.0  1.436  1.434  1.4505  1.45725 -4.000000e-03 -0.007 -0.0095
# 1       0  -5.0  1.432  1.434  1.4505  1.45725  4.330000e-17 -0.007 -0.0095
# 2       0  -5.0  1.432  1.434  1.4505  1.45725 -4.330000e-17 -0.007 -0.0095
# 3       0  -5.0  1.444  1.448  1.4505  1.45725 -1.200000e-02  0.007 -0.0095
# 4       0  -5.0  1.444  1.448  1.4505  1.45725  1.200000e-02  0.007 -0.0095
#
#        bd5  ...   ea1    ea2   ea3     ea4      ea5           ed1    ed2  \
# 0 -0.00675  ...  0.82  0.835  0.86  0.8925  0.99125  3.540000e-17 -0.015
# 1 -0.00675  ...  0.85  0.835  0.86  0.8925  0.99125 -1.000000e-02  0.015
# 2 -0.00675  ...  0.85  0.835  0.86  0.8925  0.99125  1.000000e-02  0.015
# 3 -0.00675  ...  0.87  0.885  0.86  0.8925  0.99125 -1.000000e-02 -0.015
# 4 -0.00675  ...  0.87  0.885  0.86  0.8925  0.99125  1.000000e-02 -0.015
#
#      ed3     ed4      ed5
# 0 -0.025 -0.0325 -0.09875
# ...

# %%
y=Train_Data.Target
print(y)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3645    3
# 3646    3
# 3647    3
# 3648    3
# 3649    3
# Name: Target, Length: 3650, dtype: int64

# %%
y.unique()  # Display All Unique items And Variables are available is Y (Traget) varaiable
# Out:
# array([0, 1, 4, 5, 6, 2, 3])

# %%
print('Percentage of each class in Target Variable \n')
print((Train_Data.Target.value_counts()/len(Train_Data))*100)
# Out:
# Percentage of each class in Target Variable
#
# 3    30.109589
# 6    17.808219
# 2    16.630137
# 0    11.589041
# 1     9.589041
# 4     7.452055
# 5     6.821918
# Name: Target, dtype: float64

# %%
Train_Data.corr()
# Out:
#           Target      Time           ba1           ba2           ba3  \
# Target  1.000000  0.947241  1.996656e-02  1.911043e-02  1.873535e-02
# Time    0.947241  1.000000  1.675115e-02  1.593453e-02  1.562317e-02
# ba1     0.019967  0.016751  1.000000e+00  9.927297e-01  9.757741e-01
# ba2     0.019110  0.015935  9.927297e-01  1.000000e+00  9.829214e-01
# ba3     0.018735  0.015623  9.757741e-01  9.829214e-01  1.000000e+00
# ba4     0.016158  0.014672  9.326318e-01  9.394656e-01  9.557902e-01
# ba5     0.016522  0.015876  8.476365e-01  8.538526e-01  8.686937e-01
# bd1     0.001929  0.001508  1.564193e-04  1.592890e-04  1.558953e-04
# bd2     0.008264  0.007744  1.201811e-01 -1.855838e-04 -1.914416e-04
# bd3     0.003774  0.003139  1.825435e-01  1.838745e-01 -1.541946e-04
# bd4     0.011193  0.005439  2.868143e-01  2.889068e-01  2.939234e-01
# bd5     0.002735  0.000581  3.889297e-01  3.917684e-01  3.985668e-01
# ca1    -0.099527 -0.100679 -1.084296e-01 -1.085347e-01 -1.097304e-01
# ...

# %%
plt.figure(figsize=(28,18))
HeatMap=sns.heatmap(Train_Data.corr(),annot=True)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, cross_val_score, train_test_split
Model=LogisticRegression()

# %%
X = Train_Data.drop('Target',axis=1)
y = Train_Data['Target']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
Model.fit(X_train,y_train) # fit he model
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
y_pred=Model.predict(X_test) # now predict

# %%
y_pred
# Out:
# array([6, 6, 0, ..., 0, 3, 3])

# %%
y_pred = pd.Series(y_pred).astype(str).str.replace('0', 'Minor_Damage_And_Injuries').str.replace('1', 'Significant_Damage_And_Serious_Injuries').str.replace('2', 'Significant_Damage_And_Fatalities').str.replace('3', 'Highly_Fatal_And_Damaging')

# %%
sub = pd.DataFrame(data={'bd4': Test_Data.bd4, 'Target' : y_pred})

# %%
sub.to_csv('final_pred.csv', index=False)

# %%
Y_Prediction_Train_Data=Model.predict(X)
#Y_Prediction_Train_Data
Y_Prediction_Train_Data = pd.Series(Y_Prediction_Train_Data).astype(str).str.replace('0', 'No Fault').str.replace('1', 'High Impedance 1').str.replace('2', 'High Impedance 2').str.replace('3', 'High Impedance 3').str.replace('4', 'Low Impedance 1').str.replace('5', 'Low Impedance 2').str.replace('6', 'Low Impedance 3')
sub = pd.DataFrame(data={'Independent Variable' : Train_Data.cd4, 'Independent Vari' : Train_Data.cd3, 'Target' : Y_Prediction_Train_Data})
sub
# Out:
#       Independent Variable  Independent Vari            Target
# 0            -6.250000e-02     -4.000000e-02          No Fault
# 1            -6.250000e-02     -4.000000e-02          No Fault
# 2            -6.250000e-02     -4.000000e-02          No Fault
# 3            -6.250000e-02      4.000000e-02          No Fault
# 4            -6.250000e-02      4.000000e-02          No Fault
# ...                    ...               ...               ...
# 3645          6.625000e-02      3.500000e-02  High Impedance 3
# 3646          6.625000e-02      3.500000e-02  High Impedance 3
# 3647         -8.380000e-17      6.360000e-18  High Impedance 3
# 3648         -8.380000e-17      6.360000e-18  High Impedance 3
# 3649         -8.380000e-17      6.360000e-18  High Impedance 3
#
# [3650 rows x 3 columns]

# %%
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
from sklearn.ensemble import RandomForestClassifier 

rfc = RandomForestClassifier(n_estimators=500, n_jobs=-1, random_state=10, max_features=0.5 , bootstrap=False)
rfc.fit(X,y)
# Out:
# RandomForestClassifier(bootstrap=False, max_features=0.5, n_estimators=500,
#                        n_jobs=-1, random_state=10)

# %%
Y_Predction=rfc.predict(X)
Y_Predction
# Out:
# array([0, 0, 0, ..., 3, 3, 3])

# %%
from sklearn.model_selection import cross_val_score
Cross_Val_Score = cross_val_score(rfc, X, y, cv=4, n_jobs=-1, verbose=1, scoring='f1_weighted').mean()
print("Cross Value Score is: ",Cross_Val_Score)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# Cross Value Score is:  0.8876208282565283
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:   23.5s finished

# %%
from sklearn.metrics import f1_score
Score = 100*(f1_score(y,Y_Predction,average='weighted'))
print("Score is :", Score)
# Out:
# Score is : 100.0

# %%
Y_Prediction_Train_Data=rfc.predict(X)
#Y_Prediction_Train_Data
Y_Prediction_Train_Data = pd.Series(Y_Prediction_Train_Data).astype(str).str.replace('0', 'No Fault').str.replace('1', 'High Impedance 1').str.replace('2', 'High Impedance 2').str.replace('3', 'High Impedance 3').str.replace('4', 'Low Impedance 1').str.replace('5', 'Low Impedance 2').str.replace('6', 'Low Impedance 3')
sub = pd.DataFrame(data={'f1' : Train_Data.cd4, 'f2' : Train_Data.cd3, 'Target' : Y_Prediction_Train_Data})
sub
# Out:
#                 f1            f2            Target
# 0    -6.250000e-02 -4.000000e-02          No Fault
# 1    -6.250000e-02 -4.000000e-02          No Fault
# 2    -6.250000e-02 -4.000000e-02          No Fault
# 3    -6.250000e-02  4.000000e-02          No Fault
# 4    -6.250000e-02  4.000000e-02          No Fault
# ...            ...           ...               ...
# 3645  6.625000e-02  3.500000e-02  High Impedance 3
# 3646  6.625000e-02  3.500000e-02  High Impedance 3
# 3647 -8.380000e-17  6.360000e-18  High Impedance 3
# 3648 -8.380000e-17  6.360000e-18  High Impedance 3
# 3649 -8.380000e-17  6.360000e-18  High Impedance 3
#
# [3650 rows x 3 columns]

# %%
sub.head()
# Out:
#        f1    f2    Target
# 0 -0.0625 -0.04  No Fault
# 1 -0.0625 -0.04  No Fault
# 2 -0.0625 -0.04  No Fault
# 3 -0.0625  0.04  No Fault
# 4 -0.0625  0.04  No Fault

# %%
sub.tail()
# Out:
#                 f1            f2            Target
# 3645  6.625000e-02  3.500000e-02  High Impedance 3
# 3646  6.625000e-02  3.500000e-02  High Impedance 3
# 3647 -8.380000e-17  6.360000e-18  High Impedance 3
# 3648 -8.380000e-17  6.360000e-18  High Impedance 3
# 3649 -8.380000e-17  6.360000e-18  High Impedance 3
